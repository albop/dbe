# %% [markdown]
# # More Regressions
#
# ## The World Happiness Report

# %% [markdown]
# We will analyse those data to find relationships between the happiness score and economy, family, health, freedom, trust, perception of
# corruption, generosity...

# %% [markdown]
# The dataset contains the following variables:
#
# - Country : Country name
# - Overall rank : Country ranking based on happiness score
# - Score : Individual personal happiness rating from 0 to 10.
# - GDP per capita : GDP per capita of each country in terms of purchasing power parity (PPP) (in USD)
# - Social support : Individual rating that determines whether, when you have problems, your family or friends would help you. Binary responses (0 or 1).
# - Healthy life expectancy : Healthy life expectancy at birth is based on data from the World Health Organization (WHO)
# - Freedom to make life choices : Individual rating that determines whether you are satisfied or dissatisfied with your freedom to choose what you do with your life. Binary responses (0 or 1).
# - Generosity : Generosity is the residual from the regression of the national mean of responses to the question "Have you donated money to a charity in the last month?" on GDP per capita.
# - Perceptions of corruption : Average of binary responses to two GWP questions: corruption in government and corruption in business.

# %% [markdown]
# ### I) Data exploration
#
# We start by importing the libraries we need.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula import api as smf

# %% [markdown]
# The CSV is loaded and we replace spaces in column names with underscores (so we can use them in formulas later).

# %%
df = pd.read_csv('happiness_index_2019.csv')
df.columns = df.columns.str.replace(' ', '_')

# %% [markdown]
# **Exercise 1:** Display the first 10 rows of the dataframe using `head()`.

# %%
# TODO: display the first 10 rows

# %% [markdown]
# **Exercise 2:** Check the shape and data types of the dataframe.
#
# *Hint:* use `df.shape` and `df.info()`.

# %%
# TODO: print the shape and info

# %% [markdown]
# **Exercise 3:** Compute descriptive statistics (mean, std, min, max, quartiles) for all numeric columns.
#
# *Hint:* one Pandas function does this.

# %%
# TODO: descriptive statistics

# %% [markdown]
# **Exercise 4:** Make a scatter plot of `Score` vs `GDP_per_capita`.
#
# Add axis labels and a title.
#
# *Hint:* `plt.plot(df['x'], df['y'], 'o')` makes a scatter plot.

# %%
# TODO: scatter plot of Score vs GDP_per_capita
# Don't forget: plt.xlabel(), plt.ylabel(), plt.title(), plt.show()

# %% [markdown]
# **Exercise 5:** Make a scatter plot of `Score` vs `Healthy_life_expectancy`.
#
# Add axis labels and a title.

# %%
# TODO: scatter plot of Score vs Healthy_life_expectancy

# %% [markdown]
# **Exercise 6:** Plot the correlation matrix of the main numeric variables using `sns.heatmap()`.
#
# The variables to include are already listed below. Complete the `sns.heatmap()` call.

# %%
vars_list = [
    "Score", "GDP_per_capita", "Social_support",
    "Healthy_life_expectancy", "Freedom_to_make_life_choices",
    "Generosity", "Perceptions_of_corruption"
]

fig, ax = plt.subplots(figsize=(12, 10))

# TODO: call sns.heatmap() on df[vars_list].corr()
# Hint: use annot=True, cmap="YlGnBu", fmt='.1f'

plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# **Question:** Looking at the heatmap, which variables are most strongly correlated with the Happiness Score? Which one is the least correlated?
#
# *Write your answer below:*

# %% [markdown]
# > *Your answer here*

# %% [markdown]
# ## II) Linear regression

# %% [markdown]
# ## A) Simple linear regression
#
# A simple linear regression uses **one** explanatory variable to predict the outcome.
#
# We use `statsmodels` formula API: `smf.ols("y ~ x", data)` fits the model $y = \beta_0 + \beta_1 x + u$.

# %% [markdown]
# **Exercise 7:** Run a simple regression predicting `Score` from `GDP_per_capita`.

# %%
# TODO: fit a simple OLS regression of Score on GDP_per_capita
# Store the model in model_1 and the results in res_1

# %% [markdown]
# **Interprete the output:**

# %% [markdown]
# **Exercise 8:** Visualize the regression line using `sns.regplot()`.

# %%
# TODO: use sns.regplot(x=..., y=..., data=df) to plot the regression line
# Add a title with plt.title()

# %% [markdown]
# **Exercise 9:** Run another simple regression, this time predicting `Score` from `Healthy_life_expectancy`.
#
# Store the model in `model_2` and results in `res_2`.

# %%
# TODO: simple regression of Score on Healthy_life_expectancy

# %%
# TODO: plot the regression line with sns.regplot()

# %% [markdown]
# ## B) Multiple linear regression
#
# A multiple linear regression uses **several** explanatory variables at the same time.
#
# This lets us see the effect of each variable *while controlling for the others*.

# %% [markdown]
# **Exercise 10:** Run a multiple regression predicting `Score` from:
# - `Healthy_life_expectancy`
# - `Freedom_to_make_life_choices`
# - `GDP_per_capita`
# - `Social_support`
#
# Store in `model_3` , `res_3`.
#
# *Hint:* separate variables with `+` in the formula: `"Score ~ var1 + var2 + ..."`

# %%
# TODO: multiple regression

# %% [markdown]
# **Exercise 11:** Compare the **Adjusted R-squared** of models 1, 2 and 3. Which explains happiness best?
#
# *Hint:* use `res_1.rsquared_adj`, `res_2.rsquared_adj`, `res_3.rsquared_adj`.

# %%
# TODO: print the Adjusted R-squared for each model

# %% [markdown]
# **Question:** Which model has the highest Adjusted R-squared? What does that tell us?
#
# > *Your answer here*

# %% [markdown]
# ### Polynomial Regression
#
# Sometimes the relationship between two variables is **not a straight line**.
# A **polynomial regression** allows the relationship to be curved instead of linear.
#
# Instead of estimating only a straight-line model:
#
# $$
# y = \beta_0 + \beta_1 x + \varepsilon
# $$
#
# we allow higher powers of $x$:
#
# $$
# y = \beta_0
# + \beta_1 x
# + \beta_2 x^2
# + \beta_3 x^3
# + \dots
# + \beta_n x^n
# + \varepsilon
# $$
#
# where:
#
# - $x$ = Happiness Score
# - $y$ = Healthy life expectancy
# - $n$ = degree of the polynomial
#
# Even though the curve looks nonlinear, the model is still estimated using **ordinary linear regression** — we simply add transformed versions of the same variable.
#
# Below we fit a degree-4 polynomial to see how Healthy life expectancy relates to the Score.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import numpy as np

# %% [markdown]
# **Exercise 12:** Complete the code below to fit and plot a polynomial regression.
#
# Steps:
# 1. Create polynomial features with `PolynomialFeatures(degree=4)`
# 2. Fit a `LinearRegression` on those features
# 3. Predict and plot the curve

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# --------------------------------------------------
# Variables
# --------------------------------------------------
x = df["Score"].values.reshape(-1, 1)
y = df["Healthy_life_expectancy"].values.reshape(-1, 1)

# --------------------------------------------------
# Scatter plot
# --------------------------------------------------
plt.plot(df["Score"], df["Healthy_life_expectancy"], 'o')

# --------------------------------------------------
# TODO 1 — Create polynomial features (degree 4)
# --------------------------------------------------
# polynomial_features = PolynomialFeatures(degree=...)
# x_polynomial = polynomial_features.fit_transform(...)

# --------------------------------------------------
# TODO 2 — Fit regression model
# --------------------------------------------------
# polynomial_model = LinearRegression()
# polynomial_model.fit(..., ...)

# --------------------------------------------------
# TODO 3 — Predict fitted values
# --------------------------------------------------
# y_predicted = polynomial_model.predict(...)

# --------------------------------------------------
# TODO 4 — Plot fitted polynomial curve
# --------------------------------------------------
# plt.plot(x, y_predicted, color="red", label="Polynomial fit")

plt.legend()
plt.show()

# %%
# Linear regression
lin = LinearRegression().fit(x, y)
r2_linear = lin.score(x, y)

# Polynomial regression (degree 4)
poly = PolynomialFeatures(degree=4)
x_poly = poly.fit_transform(x)

poly_model = LinearRegression().fit(x_poly, y)
r2_poly = poly_model.score(x_poly, y)

# Print 2 decimal places with f-strings  
print(f"Linear Regression R²: {r2_linear:.2f}")
print(f"Polynomial Regression R²: {r2_poly:.2f}")

# %% [markdown]
# The polynomial curve captures the slight non-linearity in the relationship. However, be cautious with high-degree polynomials — they can overfit the data.
