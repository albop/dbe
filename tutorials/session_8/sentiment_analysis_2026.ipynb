# %% [markdown]
# # Sentiment Analysis
#
# > **Data**
#
# The ultimate goal of this exercise consists performing the same
# exercise, namely sentiment analysis, using traditional NLP and GPT-4.
#
# ## The Dataset
#
# We use the [News Sentiment
# Dataset](https://www.kaggle.com/datasets/yasserh/twitter-tweets-sentiment-dataset)
# from Kaggle.
#
# 1.  **Import Dataset as a pandas dataframe**

# %%
# your code here

# %% [markdown]
# 2.  **Describe Dataset (text and graphs)**

# %%
# your code here

# %% [markdown]
# 3.  **Split Dataset into training, validation and test set. What is the
#     purpose of the validation set?**

# %%
# your code here

# %% [markdown]
# ## Text Mining
#
# 1.  **Extract features from the training dataset. What do you do with
#     non-words / punctuation?**

# %%
# your code here

# %% [markdown]
# 1.  **Convert occurrencies to frequencies. Make another version with
#     tf-idf.**

# %%
# your code here

# %% [markdown]
# 2.  **Choose a classifier to predict the sentiment on the *validation*
#     set. Compute the confusion matrix.**

# %%
# your code here

# %% [markdown]
# ## Sentiment Analysis using GPT completion
#
# 1.  **Setup an openai key. Explore openai *completion* API.**

# %%
# Check library version
from openai import OpenAI
import openai

print(openai.__version__)

# %%
# google: openai python api
# The GitHub page shows the first usage example

# %%
import os

api_key = "your-api-key-here"

# %%
# Chat completions API — send a message, get a reply
client = OpenAI(api_key=api_key)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        }
    ],
    model="gpt-4o-mini",
)

print(chat_completion.choices[0].message.content)

# %%
# your code here

# %% [markdown]
# 1.  **Design a prompt to extract the sentiment from a tweet. Test it on
#     very few tweets from the training dataset. Propose different
#     versions.**

# %%
# your code here

# %% [markdown]
# 2.  **Write a function which takes in: the prompt template, the tweet
#     text and returns the sentiment as an integer.**

# %%
# your code here

# %% [markdown]
# 3.  **Compare the results from GPT with those from NLP (on a small
#     subset of the data)**

# %%
# your code here
